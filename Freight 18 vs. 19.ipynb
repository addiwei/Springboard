# %%
import pandas as pd

xls = pd.ExcelFile('freight.xlsx')
df1 = pd.read_excel(xls, 'Q1-2018')
df2 = pd.read_excel(xls, 'Q1-2019')

# %%
df1['ORIGIN_CITY_STATE'].value_counts()
# Out:
# LAREDO, TX              101
# SOUTHHAVEN, MS           45
# QUERETARO, XX            19
# QUERETARO, MX            19
# SANTA CATARI, NL         10
# LA MIRADA, CA            10
# NEW PHILADELPHIA, OH      8
# TLAJUMULCO D, JA          7
# BERLIN,                   4
# SANTA CATARI, XX          3
# BELLE CHASSE, CA          2
# OSHKOSH, WI               2
# UNKNOWN, XX               2
# WENDELL, NC               1
# Name: ORIGIN_CITY_STATE, dtype: int64

# %%
df2['ORIGIN_CITY_STATE'].value_counts()
# Out:
# SOUTHHAVEN, MS              118
# LAREDO, TX                   43
# QUERETARO, MX                32
# QUERETARO, XX                17
# UNKNOWN, XX                  16
# NORCROSS, GA                  6
# WENDELL, NC                   5
# BERLIN,                       4
# BALVANERA DE MACEDO,, QU      4
# SANTA CATARI, XX              4
# QUERETARO, QA                 2
# EL MARQUES, QT                2
# TLAJOMULCO M, XX              2
# EL MARQUES, XX                2
# QUERATARO ME, XX              1
# NEWPORT NEWS, VA              1
# SOUTHAVEN, MS                 1
# CRANFORD, NJ                  1
# LA MIRADA, CA                 1
# PARQUE INDUS, XX              1
# Name: ORIGIN_CITY_STATE, dtype: int64

# %%
df1['DESTINATION_CITY_STATE'].value_counts()
# Out:
# SOUTHHAVEN, MS      57
# FREMONT, CA         45
# DENVER, CO          26
# ,                   18
# SOUTHAVEN, MS       12
# OSHKOSH, WI         11
# FULTON, MO          10
# WINNECONNE, WI       8
# JACKSONVILLE, FL     6
# SUMAAS, WA           5
# WENDELL, NC          4
# FREEMONT, CA         4
# BRISTOL, VA          3
# BELLE CHASSE, LA     3
# ODENTON, MD          2
# LAREDO, TX           2
# QUERETARO, XX        2
# NEWPORT, AR          2
# LEBANON, OH          2
# FLORENCE, IN         2
# MALVERN, PA          1
# CONCORD, NC          1
# SUMAS, WA            1
# COLLINGDALE, PA      1
# ASHBURN, VA          1
# COOLIDGE, AZ         1
# BERKELEY, IL         1
# CANONSBURG, PA       1
# FAIRFIELD, OH        1
# Name: DESTINATION_CITY_STATE, dtype: int64

# %%
df2['DESTINATION_CITY_STATE'].value_counts()
# Out:
# FREMONT, CA           55
# SOUTHHAVEN, MS        48
# OSHKOSH, WI           36
# ,                     31
# DENVER, CO            29
# SOUTHAVEN, MS         13
# JACKSONVILLE, FL       8
# WINNECONNE, WI         5
# FULTON, MO             4
# WENATCHEE, WA          4
# QUERETARO, MX          4
# WENDELL, NC            4
# MANSFIELD, OH          3
# SAN BERNARDI, CA       2
# NEWPORT NEWS, VA       2
# UNKNOWN, XX            2
# MORENCI, AZ            2
# NEWPORT, AR            2
# CRAWFORDSVILLE, IN     2
# ORLANDO, FL            2
# CHALFONT, PA           1
# ONTARIO, CA            1
# HINGHAM, MA            1
# GRAND PRAIRE, TX       1
# MORRISVILLE, NC        1
# Name: DESTINATION_CITY_STATE, dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x="GL_ALLOCATED_AMOUNT", y="SHIP_DATE", hue="CARRIER_NAME", data=df1)
